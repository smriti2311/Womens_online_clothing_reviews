# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math
import matplotlib.pyplot as plt
from sklearn import linear_model
# %matplotlib inline

# %%
womenc=pd.read_csv("Womens Clothing E-Commerce Reviews.csv")

# %%
womenc.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='Rating',hue='Class Name',data=womenc).legend(loc='center left', bbox_to_anchor=(1,0.5))

# %%
corRel=womenc[["Clothing ID","Age","Positive Feedback Count","Rating","Recommended IND"]].corr()
corRel
# Out:
#                          Clothing ID       Age  Positive Feedback Count  \
# Clothing ID                 1.000000  0.017972                 0.046356
# Age                         0.017972  1.000000                 0.043079
# Positive Feedback Count     0.046356  0.043079                 1.000000
# Rating                     -0.018879  0.026831                -0.064961
# Recommended IND            -0.016206  0.030622                -0.069045
#
#                            Rating  Recommended IND
# Clothing ID             -0.018879        -0.016206
# Age                      0.026831         0.030622
# Positive Feedback Count -0.064961        -0.069045
# Rating                   1.000000         0.792336
# Recommended IND          0.792336         1.000000

# %%
sns.heatmap(corRel,annot=True)

# %%
mask=np.array(corRel)
mask[np.tril_indices_from(mask)]=False
sns.heatmap(corRel,mask=mask,vmax=8,square=True,annot=True)

# %%
womenc.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
womenc.rename(columns={'Clothing ID':'Cloth_ID','Positive Feedback Count':'pos_feed_count',
                       'Review Text':'Reviews','Recommended IND':'Recommended',
                       'Department Name':'Dept_Name','Division Name':'Div_Name'},
             inplace=True)
print(womenc.columns)
# Out:
# Index(['Unnamed: 0', 'Cloth_ID', 'Age', 'Title', 'Reviews', 'Rating',
#        'Recommended', 'pos_feed_count', 'Div_Name', 'Dept_Name', 'Class Name'],
#       dtype='object')

# %%
WoW=womenc.drop(womenc.columns[0],axis=1)  #dropping extra index

# %%
WoW.head()
# Out:
#    Cloth_ID  Age                    Title  \
# 0       767   33                      NaN
# 1      1080   34                      NaN
# 2      1077   60  Some major design flaws
# 3      1049   50         My favorite buy!
# 4       847   47         Flattering shirt
#
#                                              Reviews  Rating  Recommended  \
# 0  Absolutely wonderful - silky and sexy and comf...       4            1
# 1  Love this dress!  it's sooo pretty.  i happene...       5            1
# 2  I had such high hopes for this dress and reall...       3            0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5            1
# 4  This shirt is very flattering to all due to th...       5            1
#
#    pos_feed_count        Div_Name Dept_Name Class Name
# 0               0       Initmates  Intimate  Intimates
# 1               4         General   Dresses    Dresses
# 2               0         General   Dresses    Dresses
# 3               0  General Petite   Bottoms      Pants
# 4               6         General      Tops    Blouses

# %%
WoW.corr()
# Out:
#                 Cloth_ID       Age    Rating  Recommended  pos_feed_count
# Cloth_ID        1.000000  0.017972 -0.018879    -0.016206        0.046356
# Age             0.017972  1.000000  0.026831     0.030622        0.043079
# Rating         -0.018879  0.026831  1.000000     0.792336       -0.064961
# Recommended    -0.016206  0.030622  0.792336     1.000000       -0.069045
# pos_feed_count  0.046356  0.043079 -0.064961    -0.069045        1.000000

# %% [markdown]
# ## Feature engineering to convert strings into numerical data

# %%
WoW.head()
# Out:
#    Cloth_ID  Age                    Title  \
# 0       767   33                      NaN
# 1      1080   34                      NaN
# 2      1077   60  Some major design flaws
# 3      1049   50         My favorite buy!
# 4       847   47         Flattering shirt
#
#                                              Reviews  Rating  Recommended  \
# 0  Absolutely wonderful - silky and sexy and comf...       4            1
# 1  Love this dress!  it's sooo pretty.  i happene...       5            1
# 2  I had such high hopes for this dress and reall...       3            0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5            1
# 4  This shirt is very flattering to all due to th...       5            1
#
#    pos_feed_count        Div_Name Dept_Name Class Name
# 0               0       Initmates  Intimate  Intimates
# 1               4         General   Dresses    Dresses
# 2               0         General   Dresses    Dresses
# 3               0  General Petite   Bottoms      Pants
# 4               6         General      Tops    Blouses

# %%
WoW.isnull().head()
# Out:
#    Cloth_ID    Age  Title  Reviews  Rating  Recommended  pos_feed_count  \
# 0     False  False   True    False   False        False           False
# 1     False  False   True    False   False        False           False
# 2     False  False  False    False   False        False           False
# 3     False  False  False    False   False        False           False
# 4     False  False  False    False   False        False           False
#
#    Div_Name  Dept_Name  Class Name
# 0     False      False       False
# 1     False      False       False
# 2     False      False       False
# 3     False      False       False
# 4     False      False       False

# %% [markdown]
# ### Data Cleaning(replacing null values with default values)

# %%
WoW["Title"].fillna("Basic", inplace=True)
WoW["Reviews"].fillna("Satisfactory", inplace=True)
WoW["Div_Name"].fillna("General", inplace=True)
WoW["Dept_Name"].fillna("Clothing", inplace=True)

# %%
WoW.isnull().sum()
# Out:
# Cloth_ID           0
# Age                0
# Title              0
# Reviews            0
# Rating             0
# Recommended        0
# pos_feed_count     0
# Div_Name           0
# Dept_Name          0
# Class Name        14
# dtype: int64

# %%
WoW=WoW.drop(WoW.columns[9],axis=1)
WoW.head()
# Out:
#    Cloth_ID  Age                    Title  \
# 0       767   33                    Basic
# 1      1080   34                    Basic
# 2      1077   60  Some major design flaws
# 3      1049   50         My favorite buy!
# 4       847   47         Flattering shirt
#
#                                              Reviews  Rating  Recommended  \
# 0  Absolutely wonderful - silky and sexy and comf...       4            1
# 1  Love this dress!  it's sooo pretty.  i happene...       5            1
# 2  I had such high hopes for this dress and reall...       3            0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5            1
# 4  This shirt is very flattering to all due to th...       5            1
#
#    pos_feed_count        Div_Name Dept_Name
# 0               0       Initmates  Intimate
# 1               4         General   Dresses
# 2               0         General   Dresses
# 3               0  General Petite   Bottoms
# 4               6         General      Tops

# %%
plt.figure(figsize=(8,10))
sns.countplot(y='Dept_Name',data=WoW, hue='Div_Name').legend(loc='center left', bbox_to_anchor=(1,0.5))

# %%
WoW.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 9 columns):
# Cloth_ID          23486 non-null int64
# Age               23486 non-null int64
# Title             23486 non-null object
# Reviews           23486 non-null object
# Rating            23486 non-null int64
# Recommended       23486 non-null int64
# pos_feed_count    23486 non-null int64
# Div_Name          23486 non-null object
# Dept_Name         23486 non-null object
# dtypes: int64(5), object(4)
# memory usage: 1.6+ MB

# %%
WoW['Dept_Name'].value_counts()
# Out:
# Tops        10468
# Dresses      6319
# Bottoms      3799
# Intimate     1735
# Jackets      1032
# Trend         119
# Clothing       14
# Name: Dept_Name, dtype: int64

# %% [markdown]
# ### Feature Engineering

# %%
dep_name=pd.unique(WoW['Dept_Name'])
dep_name
# Out:
# array(['Intimate', 'Dresses', 'Bottoms', 'Tops', 'Jackets', 'Trend',
#        'Clothing'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
leo=LabelEncoder()

# %% [markdown]
# TypeError: '<' not supported between instances of 'str' and 'float'
# this error occurs when we have missing values in our data

# %%
dept_labels=leo.fit_transform(WoW['Dept_Name'])
dept_labels
# Out:
# array([3, 2, 2, ..., 2, 2, 2])

# %%
#mapping of values in dictionaries using dictionary comprehension
dept_map={index:label for index, label in enumerate(leo.classes_)}
dept_map
# Out:
# {0: 'Bottoms',
#  1: 'Clothing',
#  2: 'Dresses',
#  3: 'Intimate',
#  4: 'Jackets',
#  5: 'Tops',
#  6: 'Trend'}

# %%
WoW['DeptLabel']=dept_labels   # adding the column dept_map in the dataframe
WoW[['Cloth_ID','Recommended','Dept_Name','DeptLabel']].head()
# Out:
#    Cloth_ID  Recommended Dept_Name  DeptLabel
# 0       767            1  Intimate          3
# 1      1080            1   Dresses          2
# 2      1077            0   Dresses          2
# 3      1049            1   Bottoms          0
# 4       847            1      Tops          5

# %%
WoW.sample(frac=0.05,random_state=4)
# Out:
#        Cloth_ID  Age                                   Title  \
# 13737      1078   50                       Love this dress!!
# 12670      1110   48                      10 lbs. no thanks!
# 21523       975   37                                So close
# 10787      1078   35                                   Basic
# 2347        132   45                                Amazing!
# 8175        831   24                          Easy breezy :)
# 12513       936   47                       Gorgeous sweater!
# 8853        283   37                   Very flattering shirt
# 5183        927   39              A tad scratchier than most
# 10014      1110   46                          Violetta dress
# 10129       872   53                        Great casual top
# 22641       895   49                                   Basic
# 12141       865   26                     Material too flimsy
# 17346      1022   42                 Super comfy , great fit
# 22217       717   25                       Comfort and style
# 5221       1099   62                       I don't get it...
# 6558       1078   69                            Unique style
# 13470      1024   63                          Cute but tight
# 17900       861   47                     Complimentary color
# 5120        678   40                                   Basic
# 3771       1025   37                      Worth every penny!
# 19215      1020   38           Fun skirt with a little twist
# 15834      1028   48                                   Basic
# 21758       863   40                             Not sure...
# 12618       820   51                                   Basic
# 18812       862   35                         Classy cowlneck
# 2590        975   37                                   Basic
# 15380      1083   40                      Cute casual dress.
# 15096       881   21       Pretty but the doesn't fit right.
# 3485       1056   46                Pilcro stet chino capris
# ...         ...  ...                                     ...
# 2131        862   54                                   Basic
# 16343               0  General Petite   Dresses          2
# 22216               1       Initmates  Intimate          3
# 971                 0         General      Tops          5
# 18255               0       Initmates  Intimate          3
# 10674               0         General   Bottoms          0
# 18969               1         General   Dresses          2
# 4882                2       Initmates  Intimate          3
# 17736               0  General Petite   Dresses          2
# 21106               0         General      Tops          5
# 21451               0         General   Bottoms          0
# 21404               0  General Petite   Bottoms          0
# 12334               4         General   Bottoms          0
#
# [1174 rows x 10 columns]

# %%
sns.jointplot(data=WoW, x='Age',y='DeptLabel',kind='reg',ylim=(0,2),color='red',size=4.5,ratio=4)
# Out:
# C:\Users\Dilip\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Predictive Modelling through linear regression model

# %%
y=WoW[['Rating']]
x=WoW[['DeptLabel']]
regmodel=linear_model.LinearRegression()
regmodel.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#providing DeptLabel 4 and checking if it provides the rating or not
newp=5
newp=np.array(newp)
newp=newp.reshape(-1,1)
pred=regmodel.predict(newp)
pred
# Out:
# array([[4.16674983]])

# %% [markdown]
# ### We conclude that DeptLabel=4 i.e. Jackets have mostly the rating of 4

# %%
WoW.describe()
# Out:
#            Cloth_ID           Age        Rating   Recommended  pos_feed_count  \
# count  23486.000000  23486.000000  23486.000000  23486.000000    23486.000000
# mean     918.118709     43.198544      4.196032      0.822362        2.535936
# std      203.298980     12.279544      1.110031      0.382216        5.702202
# min        0.000000     18.000000      1.000000      0.000000        0.000000
# 25%      861.000000     34.000000      4.000000      1.000000        0.000000
# 50%      936.000000     41.000000      5.000000      1.000000        1.000000
# 75%     1078.000000     52.000000      5.000000      1.000000        3.000000
# max     1205.000000     99.000000      5.000000      1.000000      122.000000
#
#           DeptLabel
# count  23486.000000
# mean       3.195052
# std        1.887257
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        5.000000
# max        6.000000

# %% [markdown]
# ### Through test_train_split model
# ### Training 20% of our entire data and testing on the rest of it

# %%
from sklearn.model_selection import train_test_split

# %%
WoW.head()
# Out:
#    Cloth_ID  Age                    Title  \
# 0       767   33                    Basic
# 1      1080   34                    Basic
# 2      1077   60  Some major design flaws
# 3      1049   50         My favorite buy!
# 4       847   47         Flattering shirt
#
#                                              Reviews  Rating  Recommended  \
# 0  Absolutely wonderful - silky and sexy and comf...       4            1
# 1  Love this dress!  it's sooo pretty.  i happene...       5            1
# 2  I had such high hopes for this dress and reall...       3            0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5            1
# 4  This shirt is very flattering to all due to th...       5            1
#
#    pos_feed_count        Div_Name Dept_Name  DeptLabel
# 0               0       Initmates  Intimate          3
# 1               4         General   Dresses          2
# 2               0         General   Dresses          2
# 3               0  General Petite   Bottoms          0
# 4               6         General      Tops          5

# %%
x=WoW[['Cloth_ID','Age','Rating','pos_feed_count','DeptLabel']]

# %%
y=WoW[['Recommended']]

# %%
#WoW2=pd.DataFrame(data=WoW)  #creating a new dataframe so that original dataframe not affected

# %% [markdown]
# # Building Logistic Regression Model

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=101)

# %%
X_train.head()
# Out:
#       Cloth_ID  Age  Rating  pos_feed_count  DeptLabel
# 3211       862   41       5               5          5
# 8841      1025   46       5               0          0
# 291        984   71       5               0          4
# 5857      1033   45       5               0          0
# 8693       774   47       1              20          3

# %% [markdown]
# # Training and Predicting

# %%
from sklearn.linear_model import LogisticRegression

# %%
LRModel=LogisticRegression()

# %%
LRModel.fit(X_train,y_train)
# Out:
# C:\Users\Dilip\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Dilip\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# # Testing out model

# %%
prediction_cl=LRModel.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test,prediction_cl))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.82      0.80       823
#            1       0.96      0.95      0.96      3875
#
#    micro avg       0.93      0.93      0.93      4698
#    macro avg       0.87      0.89      0.88      4698
# weighted avg       0.93      0.93      0.93      4698

# %% [markdown]
# ### creating a new row in dataframe

# %%
x=['Cloth_ID','Age','Rating','pos_feed_count','DeptLabel']
data=[5463,23,3,6,7]
recom=pd.DataFrame([data],columns=x)
recom.head()
# Out:
#    Cloth_ID  Age  Rating  pos_feed_count  DeptLabel
# 0      5463   23       3               6          7

# %%
WoW.head()
# Out:
#    Cloth_ID  Age                    Title  \
# 0       767   33                    Basic
# 1      1080   34                    Basic
# 2      1077   60  Some major design flaws
# 3      1049   50         My favorite buy!
# 4       847   47         Flattering shirt
#
#                                              Reviews  Rating  Recommended  \
# 0  Absolutely wonderful - silky and sexy and comf...       4            1
# 1  Love this dress!  it's sooo pretty.  i happene...       5            1
# 2  I had such high hopes for this dress and reall...       3            0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5            1
# 4  This shirt is very flattering to all due to th...       5            1
#
#    pos_feed_count        Div_Name Dept_Name  DeptLabel
# 0               0       Initmates  Intimate          3
# 1               4         General   Dresses          2
# 2               0         General   Dresses          2
# 3               0  General Petite   Bottoms          0
# 4               6         General      Tops          5

# %%
prediction_cl=LRModel.predict(recom)

# %%
print(prediction_cl)
# Out:
# [0]

# %% [markdown]
# ### This shows that given the details the product is not recommended

# %%
WoW['Rating'].value_counts().plot(kind='bar')

# %%
deptnumber=WoW['Dept_Name'].value_counts()
deptnumber[:10].plot(kind='bar')

# %%
WoW2=WoW[WoW['Rating']==5]

# %%
WoW2.head()
# Out:
#    Cloth_ID  Age                 Title  \
# 1      1080   34                 Basic
# 3      1049   50      My favorite buy!
# 4       847   47      Flattering shirt
# 6       858   39  Cagrcoal shimmer fun
# 8      1077   24            Flattering
#
#                                              Reviews  Rating  Recommended  \
# 1  Love this dress!  it's sooo pretty.  i happene...       5            1
# 3  I love, love, love this jumpsuit. it's fun, fl...       5            1
# 4  This shirt is very flattering to all due to th...       5            1
# 6  I aded this in my basket at hte last mintue to...       5            1
# 8  I love this dress. i usually get an xs but it ...       5            1
#
#    pos_feed_count        Div_Name Dept_Name  DeptLabel
# 1               4         General   Dresses          2
# 3               0  General Petite   Bottoms          0
# 4               6         General      Tops          5
# 6               1  General Petite      Tops          5
# 8               0         General   Dresses          2

# %%
WoW2['Dept_Name'].unique()
deptnumber=WoW2['Dept_Name'].value_counts()
deptnumber[:6].plot(kind='bar')
